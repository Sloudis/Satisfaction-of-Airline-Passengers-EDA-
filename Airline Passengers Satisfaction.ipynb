# %% [markdown]
# <a id="cleaning"></a>
# # <p style="padding:15px; background-color:#370B4C; font-family:fantasy; font-size:150%; color:#f2f2f0; text-align:center; border-radius: 20px 20px; font-weight:normal">Satisfaction of Airline Passengers ✈️</p>

# %% [markdown]
# <p style="
#     font-size: 24px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #370B4C;
# ">
#     <b>Dataset</b> 🗃️
# </p>
#
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#   You can find the dataset used in this notebook here:<br><br>
#    <a href="https://www.kaggle.com/datasets/mysarahmadbhat/airline-passenger-satisfaction"><b>Airline Passenger Satisfaction</b></a>
# </p>

# %% [markdown]
# <p style="
#     font-size: 24px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #370B4C;
# ">
#     <b>Notebook Description</b> 📜
# </p>
#
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#    This notebook aims to analyze and visualize the reviews and satisfaction of airline passengers. The datatset description is as follows:<br><br>
#     <i>&emsp;The dataset contains 129.880 passenger reviews. Each Review consists of customer satisfaction scores (0-5) on diffrent features the airline offers such as cleanliness, comfort, baggage handling etc. There are a total of 14 of those categories that the passenger has rated, as well as an aditional category, the overall satisfaction, divided into two classes: satisfied and neutral or dissatisfied.Each review also contains aditional information about the passenger (Gender, Age etc) and about the flight (flight distance, departure and arrival delays etc). <br></i>
#     <br>This notebook consists of 4 sections:<br><br>
#     <i>&emsp; The first section is <b>Data Cleaning</b>. We are looking for imperfections in the dataset such as missing values, false data types etc, which make the dataset ineffective and hard to work with. We will try to fix those issues and improve the quality of the dataset.<br><br>
#         &emsp; The second section is <b>Data Visualization</b>. In this section, we will represent the data through use of common graphics, such as plots,charts and heatmaps. These visual graphs will allow us to get a better understanding of the dataset and find correlations between its features.<br><br>
#         &emsp; The third section is <b>Passenger Reviews</b>. Here, we analyze the passenger reviews on every feature the airline offers. We try to find where there is room for improvement and we also compare the data with the overall satisfaction of the passenger in order to see the impact that every category has on the overall experience of the passenger.<br><br>
#         &emsp; The fourth section is <b>Summary</b>. In this section we summarise the findings of the previous sections and suggest solutions and improvements.
# </i>
#         </p>
#
#
# <p style="
#     font-size: 24px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #370B4C;
# ">
#     <b>Task</b> 💡
# </p>
#
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#   &emsp; Our job is to visualize the passenger information and scores, find correlations between the ratings and overall satisfaction of the passenger and lastly analyze the results and where there is need for improvement from the airline.
# </p>

# %% [markdown]
# <p style="
#     font-size: 28px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#           border-bottom: 2px solid #370B4C;
# ">
#     <b>Table of Contents</b> 📔
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     The table of contents provides pleasurable navigation through the whole notebook. You can easily navigate through sections and return to TOC.
# </p>
#
# <blockquote class="anchor" id="top" style="
#     margin-right: auto;
#     margin-left: auto;
#     padding: 10px;
#     background-color: #370B4C;
#     border-radius: 2px;
#     border: 1px solid #370B4C;
# ">
# <ol style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     color: #F2F2F0;
#     margin-top: 15px;
#     margin-bottom: 15px;
# ">
#     <li><a href="#cleaning"><span style="color: #F2F2F0"> Data Cleaning 🧹</span></a>
#     <ol  class="numbered-list" class="numbered-list"  style="
#         font-size: 16px;
#         font-family: 'JetBrains Mono';
#         color: #F2F2F0;
#     ">
#         <li><a href="#setup"><span style="color: #F2F2F0">Setup</span></a></li>
#         <li><a href="#glance-at-dataset"><span style="color: #F2F2F0">Glance at the dataset</span></a></li>
#         <li><a href="#missing-values-general-cleaning"><span style="color: #F2F2F0">Missing Values &amp; General Cleaning</span>
#         <li><a href="#data-distribution"><span style="color: #F2F2F0">Data Distribution</span>
# </a></li>
#     </ol>
#     <li><a href="#data-visualizations"><span style="color: #F2F2F0">Data Visualizations 📊</span></a>
#     <ol class="numbered-list" class="numbered-list" style="
#         font-size: 16px;
#         font-family: 'JetBrains Mono';
#         color: #F2F2F0;
#     ">
#         <li><a href="#gender"><span style="color: #F2F2F0">Gender</span></a></li>
#         <li><a href="#age"><span style="color: #F2F2F0">Age</span></a></li>
#         <li><a href="#customer-type"><span style="color: #F2F2F0">Customer Type</span></a></li>
#         <li><a href="#type-of-travel"><span style="color: #F2F2F0">Type of Travel</span></a></li>
#         <li><a href="#class"><span style="color: #F2F2F0">Class</span></a></li>
#         <li><a href="#delays"><span style="color: #F2F2F0">Delays</span></a></li>
#         <li><a href="#heatmap"><span style="color: #F2F2F0">Heatmap</span></a></li>
#     </ol>
#     <li><a href="#passenger-reviews"><span style="color: #F2F2F0">Passenger Reviews ⭐</span></a>
#     <ol class="numbered-list" class="numbered-list" style="
#         font-size: 16px;
#         font-family: 'JetBrains Mono';
#         color: #F2F2F0;
#     ">
#         <li><a href="#departure-arrival-time-convenience"><span style="color: #F2F2F0">Departure and Arrival Time Convenience</span></a></li>
#         <li><a href="#ease-of-online-booking"><span style="color: #F2F2F0">Ease of Online Booking </span></a></li>
#         <li><a href="#check-in-service"><span style="color: #F2F2F0">Check-in Service</span></a></li>
#         <li><a href="#online-boarding"><span style="color: #F2F2F0">Online Boarding</span></a></li>
#         <li><a href="#gate-location"><span style="color: #F2F2F0">Gate Location</span></a></li>
#         <li><a href="#on-board-service"><span style="color: #F2F2F0">On-board Service</span></a></li>
#         <li><a href="#seat-comfort"><span style="color: #F2F2F0">Seat Comfort</span></a></li>
#         <li><a href="#leg-room-service"><span style="color: #F2F2F0">Leg Room Service</span></a></li>
#         <li><a href="#cleanliness"><span style="color: #F2F2F0">Cleanliness</span></a></li>
#         <li><a href="#food-drink"><span style="color: #F2F2F0">Food &amp; Drink</span></a></li>
#         <li><a href="#in-flight-service"><span style="color: #F2F2F0">In-flight Service</span></a></li>
#         <li><a href="#in-flight-wifi-service"><span style="color: #F2F2F0">In-flight Wifi Service</span></a></li>
#         <li><a href="#in-flight-entertainment"><span style="color: #F2F2F0">In-flight Entertainment</span></a></li>
#         <li><a href="#baggage-handling"><span style="color: #F2F2F0">Baggage Handling</span></a></li>
#         </ol>
#   <li><a href="#summary"><span style="color: #F2F2F0">Summary 🧐</span></a>
# </ol>
# </blockquote>

# %% [markdown]
# <a id="cleaning"></a>
# # <p style="padding:15px; background-color:#370B4C; font-family:fantasy; font-size:150%; color:#f2f2f0; text-align:center; border-radius: 20px 20px; font-weight:normal">1. Data Cleaning 🧹</p>

# %% [markdown]
# <p style="
#     font-size: 24px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #633075;
# ">
#     <b>About Section</b> 💡
# </p>
#
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#    &emsp; In this section, we are looking for imperfections in the dataset such as missing values, false data types etc, which make the dataset ineffective and hard to work with. We will try to fix those issues and improve the quality of the dataset.
# </p>

# %% [markdown]
# <a id="setup"></a>
# <p style="
#     font-size: 30px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#   <b> ⏩ Setup <b>
# </p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import MultipleLocator

plt.style.use('bmh')

df=pd.read_csv('airline_passenger_satisfaction.csv')

# %%
# Used to calculate percentages on pie plots 

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct
# ----------------------------------------------------------------------
# Used to generate colors for the plots

def generate_colors(num):
    if num==1:
        colors=''
        lst = list('ABCDEF0123456789')
        for i in range(num):
            colors='#'+''.join(np.random.choice(lst, 6))
    else:
        colors = []
        lst = list('ABCDEF0123456789')

        for i in range(num):
            colors.append('#'+''.join(np.random.choice(lst, 6)))
        
    return colors

# %% [markdown]
# <a id="glance-at-dataset"></a>
# <p style="
#     font-size: 30px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#     <b> ⏩ Glance at the Dataset </b>
# </p>

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
df.shape
# Out:
# (129880, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129880.000000
# mean       15.091129                                3.057599
# std        38.465650                                1.526741
# min         0.000000                                0.000000
# ...

# %%
#Displaying all Columns
pd.set_option('display.max_columns',24)

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %% [markdown]
# <p style="
#     font-size: 22px;
#     font-family: 'JetBrains Mono';
# ">
#  <b> Conclusions:<b>
# </p>
#
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#  • We can see that all numerical columns are either int or float type. So we dont need to change any data types.
#
# </p>
#
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#   • There are 24 categories and 129880 entries.
#      </p>

# %% [markdown]
# <a id="missing-values-general-cleaning"></a>
# <p style="
#     font-size: 30px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#   <b> ⏩ Missing Values &amp; General Cleaning <b>
# </p>

# %%
df.isnull().sum()
# Out:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# ...

# %% [markdown]
# <p style="
#     font-size: 22px;
#     font-family: 'JetBrains Mono';
# ">
#   Since the missing values are very few compared to the total entries, we will replace them with 0.
# </p>

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                                        0
# Gender                                    0
# Age                                       0
# Customer Type                             0
# Type of Travel                            0
# Class                                     0
# Flight Distance                           0
# Departure Delay                           0
# Arrival Delay                             0
# Departure and Arrival Time Convenience    0
# Ease of Online Booking                    0
# Check-in Service                          0
# Online Boarding                           0
# Gate Location                             0
# On-board Service                          0
# Seat Comfort                              0
# Leg Room Service                          0
# Cleanliness                               0
# Food and Drink                            0
# In-flight Service                         0
# In-flight Wifi Service                    0
# ...

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#  ID column is not usefull so I will drop it from the DataFrame.
# </p>

# %%
df.drop('ID',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0    Male   48    First-time       Business  Business              821
# 1  Female   35     Returning       Business  Business              821
# 2    Male   41     Returning       Business  Business              853
# 3    Male   50     Returning       Business  Business             1905
# 4  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
#    Ease of Online Booking  Check-in Service  Online Boarding  Gate Location  \
# ...

# %% [markdown]
# <a id="data-distribution"></a>
# <p style="
#     font-size: 30px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#   <b> ⏩ Data Distribution <b>
# </p>

# %%
numeric_df=df._get_numeric_data()

# %%
sns.set_style('ticks')
fig = plt.figure(figsize=(15,18),dpi=300)

for i,column_name in enumerate(numeric_df):
    plt.subplot(9,2,i+1)
    ax=sns.boxplot(x=column_name,data=df,color=generate_colors(1))
    ax.set_title(column_name,size=15)
    plt.xlabel('')
    
plt.subplots_adjust(hspace = 0.8, wspace=0.3)
fig.suptitle("Distribution of Numerical Columns",size=20,fontweight='bold',y=0.92)
plt.show()

# %% [markdown]
# <p style="
#     font-size: 22px;
#     font-family: 'JetBrains Mono';
# ">
#  <b> From the boxplots we can conclude that:<b>
# </p>
#
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#  • There aren't any negative numbers.
#
# </p>
#
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#   • All the reviews are from 0 to 5 (which is correct).
#      </p>
#
#
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#   • The age , departure delay,arrival delay and flight distance values are logical.
#      </p>

# %% [markdown]
# <a id="data-visualizations"></a>
# # <p style="padding:15px; background-color:#370B4C; font-family:fantasy; font-size:150%; color:#f2f2f0; text-align:center; border-radius: 20px 20px; font-weight:normal">2.  Data Visualizations 📊 </p>

# %% [markdown]
# <p style="
#     font-size: 24px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #633075;
# ">
#     <b>About Section</b> 💡
# </p>
#
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#    &emsp; In this section, we will represent the data through use of common graphics, such as plots,charts and heatmaps. These visual graphs will allow us to get a better understanding of the dataset and find correlations between its features.
# </p>

# %% [markdown]
# <a id="gender"></a>
# <p style="
#     font-size: 30px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#   <b> ⏩ Gender <b>
# </p>

# %%
df['Gender'].value_counts()
# Out:
# Female    65899
# Male      63981
# Name: Gender, dtype: int64

# %%
Gender_percentage=dict((df['Gender'].value_counts()/df.shape[0])*100)
print('Distribution of Genders:\n')
print('Females: {Female}%  \nMales: {Male}% '.format(Female="{:.2f}".format(Gender_percentage['Female']),
Male="{:.2f}".format(Gender_percentage['Male'])))
# Out:
# Distribution of Genders:
#
# Females: 50.74%
# Males: 49.26%

# %%
plt.figure(figsize=(4,3),dpi=120)

plt.style.use('bmh')

plt.title('Gender Distribution',size=20,y=1.5,x=0.5)

explode=(.05,.1)

plt.pie(df['Gender'].value_counts(),labels=['Female','Male'],shadow=True,colors=['#009EFA','#B0B0EB'],
autopct=make_autopct(df['Gender'].value_counts()),pctdistance=0.5,radius=1.8,startangle=133,explode=explode)


plt.show()

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#  • The number of females is slightly higher than the number of males.
#
# </p>

# %% [markdown]
# <a id="age"></a>
#
#
#
# <p style="
#     font-size: 30px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    <b>⏩ Age <b>
# </p>

# %%
sns.set_style('ticks')


fig, ax = plt.subplots()

fig.figsize=(3,2)
fig.dpi=120
ax.minorticks_on()
ax.xaxis.set_minor_locator(MultipleLocator(5))

plt.title('Box Plot of Ages',size=20,fontweight='bold',y=1.05)


sns.boxplot(x='Age',data=df,color='#6190DC')

plt.xticks(np.arange(0,110,10))
plt.xlabel('Age',size=15)

plt.show()

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#  • We can see that there are no anomalies in the Ages column (No negative ages or big integers).
#
# </p>

# %%
fig, ax = plt.subplots()

fig.figsize=(20,5)
fig.dpi=120
ax.minorticks_on()
ax.xaxis.set_minor_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(MultipleLocator(100))

plt.title('Histogram of Ages',size=20,fontweight='bold',y=1.04)

sns.histplot(x='Age',data=df,color='#605E5E',edgecolor='black',kde=True,line_kws={'lw': 1,'linestyle':'--'})

plt.xlabel('Age',size=15)
plt.ylabel('Count',size=15)


plt.show()

# %%
plt.style.use('bmh')
sns.set_style('ticks')

fig, ax = plt.subplots()

fig.figsize=(3,2)
fig.dpi=130
ax.minorticks_on()
ax.xaxis.set_minor_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(MultipleLocator(100))


plt.title('Histogram of Ages Compared to Flight Class',size=20,fontweight='bold',y=1.04)

sns.histplot(x='Age',data=df,color=['#605E5E'],edgecolor='black',hue='Class',kde=True,line_kws={'lw': 1,'linestyle':'--'})


plt.xlabel('Age',size=15)
plt.ylabel('Count',size=15)

plt.legend(['Economy Plus','Economy'  ,'Business'],fontsize='8')

plt.show()

# %% [markdown]
# <a id="customer-type"></a>
#
#
#
# <p style="
#     font-size: 30px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#   <b> ⏩ Customer Type <b>
# </p>

# %%
df['Customer Type'].value_counts()
# Out:
# Returning     106100
# First-time     23780
# Name: Customer Type, dtype: int64

# %%
plt.figure(figsize=(4,3),dpi=110)

plt.style.use('bmh')

plt.title('Pie Plot of Customer Type ',size=20,y=1.5,x=0.5)

explode=(.05,.1)

plt.pie(df['Customer Type'].value_counts(),labels=['Returning','First-Time'],shadow=True,colors=['#0167A1','#01A110'],
autopct=make_autopct(df['Customer Type'].value_counts()),pctdistance=0.5,radius=1.8,startangle=133,explode=explode)


plt.show()

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#  <b>From the graph above:</b><br><br>
#  • We come to the conclusion that most of the airline customers are returning ones. Less than 20% are first time customers.
#
#
#
# </p>

# %% [markdown]
# <a id="type-of-travel"></a>
#
#
#
# <p style="
#     font-size: 30px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#  <b>  ⏩ Type of Travel <b>
# </p>

# %%
df['Type of Travel'].value_counts()
# Out:
# Business    89693
# Personal    40187
# Name: Type of Travel, dtype: int64

# %%
plt.figure(figsize=(10,5),dpi=200)


plt.subplot(1,2,1)

plt.style.use('bmh')
sns.set_style('ticks')




plt.title('Reason For Travelling',size=20,fontweight='bold',y=1.1)



sns.countplot(x='Type of Travel',hue='Type of Travel',data=df,palette='BuPu')

plt.xlabel('')
plt.ylabel('Count',size=15)

plt.yticks(np.arange(0,100000,10000))


plt.subplot(1,2,2)


plt.title('Reason For Travelling Compared to Age',size=20,fontweight='bold',y=1.1)

sns.violinplot(x='Type of Travel',y='Age',hue='Type of Travel',data=df,palette=['#3F91DE','#DE3F3F'])


plt.yticks(np.arange(0,100,10))


plt.ylabel('Age',size=15)
plt.xlabel('')


plt.subplots_adjust(hspace = 0.6, wspace=0.5)

plt.show()

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#  <b>Observations:</b><br><br>
# • Passengers flying for business purposes are almost triple than those flying for personal. <br>
# • Number of passengers flying for personal reasons is consinstent at any age. <br>
# • Most passengers flying for business are between 25-60.     <br>
#
#
# </p>

# %% [markdown]
# <a id="class"></a>
#
#
#
# <p style="
#     font-size: 30px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#   <b> ⏩ Class <b>
# </p>

# %%
fig, ax = plt.subplots()
fig.figsize=(5,3)
fig.dpi=120

sns.set_style('ticks')

ax.minorticks_on()
ax.yaxis.set_minor_locator(MultipleLocator(5000))
ax.xaxis.set_minor_locator(MultipleLocator(1))

plt.title('Class',size=20,fontweight='bold',y=1.1)


sns.countplot(x='Class',hue='Class',data=df)

plt.ylabel('')
plt.xlabel('')

plt.show()

# %%
plt.figure(figsize=(10, 5),dpi=200)


plt.subplot(1,2,1)


sns.set_style('ticks')

ax.minorticks_on()
ax.yaxis.set_minor_locator(MultipleLocator(10000))


plt.title('Passenger Satisfaction-Class',size=20,fontweight='bold',y=1.1)



sns.countplot(x='Class',hue='Satisfaction',data=df,palette=['#055df5','#c23a00'])

plt.xlabel('')
plt.ylabel('')

plt.yticks(np.arange(0,70000,10000))

plt.legend(fontsize='9')

plt.subplot(1,2,2)


plt.title('Class-Flight Distance',size=20,fontweight='bold',y=1.1)





sns.histplot(x='Flight Distance',data=df,hue='Class',pmax=.1,kde=True,line_kws={'lw': 1,'linestyle':'--'})

plt.ylabel('',size=15)
plt.xlabel('Distance',size=15)


plt.subplots_adjust(hspace = 0.6, wspace=0.5)

plt.legend(['Economy Plus', 'Economy' ,'Business' ],fontsize='10')

plt.show()

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#  <b>Observations:</b><br><br>
# • Very few people fly in the economy plus class. They usually prefer Economy or Business. <br>
# • More than 80% of passengers flying in economy are either Neutral or Dissatisfied. That shows us that it needs some impromevent. <br>
# • Passengers that fly for long distances almost always prefer business class. Probably because it is more comfortable.     <br>
#
#
# </p>

# %% [markdown]
# <a id="delays"></a>
# <p style="
#     font-size: 30px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    <b> ⏩ Delays <b>
# </p>

# %%
sns.set_style('darkgrid')


fig, ax = plt.subplots(1, 2, figsize=(16,8))



sns.boxplot(x='Departure Delay',data=df,color=generate_colors(1),ax=ax[0])
ax[0].set_title('Departure Delay',size=20,fontweight='bold')
ax[0].set_xlabel('') 
    
    

sns.boxplot(x='Arrival Delay',data=df,color=generate_colors(1),ax=ax[1])
ax[1].set_title('Arrival Delay',size=20,fontweight='bold')
ax[1].set_xlabel('') 


plt.show()

# %%
departure_delay_pct=round((df.loc[df['Departure Delay']>60].shape[0]/df.shape[0])*100,2)
arrival_delay_pct=round((df.loc[df['Arrival Delay']>60].shape[0]/df.shape[0])*100,2)
print('Delay over an hour long:\n')
print(f'Departure delay: {departure_delay_pct} %')
print(f'Arrival delay: {arrival_delay_pct} %')
# Out:
# Delay over an hour long:
#
# Departure delay: 6.91 %
# Arrival delay: 7.0 %

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#  <b>Insights:</b><br><br>
# • We can see that delays over an hour are at a small percentage, which is a good thing. <br>
#     <br><b>Note:</b><br>
# • The 7% of arrival delays are also directly connected to the departure delays which means the percentages are not that accurate.
#
#
# </p>

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

plt.figure(figsize=(16,8))

plt.title('Satisfaction based on Delay',size=20,fontweight='bold')

sns.scatterplot(y='Departure Delay',data=df,x='Arrival Delay',hue='Satisfaction',palette='husl')

plt.xlabel('Arrival Delay',size=18)
plt.ylabel('Departure Delay',size=18)

plt.legend(fontsize='13')
plt.show()

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#  <b>Conclusion:</b><br><br>
# • The longer the delay is more people are Dissatisfied (or Neutral) and less are Satisfied, which is expected.  <br>
#     <br>
#
#
# </p>

# %% [markdown]
# <a id="heatmap"></a>
# <p style="
#     font-size: 30px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#   <b> ⏩ Heatmap <b>
# </p>

# %%
'''Making a Dataframe with only the numerical columns in order to draw the heatmap. Also replacing The satisfaction 
column Satisfied and Neutral or Dissatisfied with 1 and 0 correspondingly.'''
sns.set_style('darkgrid')
temp_df=df.copy()
temp_df['Satisfaction']=temp_df['Satisfaction'].map({'Satisfied': 1, 'Neutral or Dissatisfied': 0})

numerical_df=temp_df._get_numeric_data().corr()

mask = np.triu(numerical_df)

plt.figure(figsize=(20,8),dpi=150)

sns.heatmap(numerical_df,mask=mask,cmap='BuPu',annot=True)

plt.show()

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
#  <b>Observations:</b><br><br>
# • We can see that there is a match between arrival delay and departure delay which is expected. <br>
# • Food and Drink is associated with In-Flight Entertainment. <br>
# • There is a correlation between Seat Comfort and Cleanless.    <br>
# • Passenger satisfaction is dependent on all of the features of the dataset (Online Boarding, Seat Comfort etc.) almost equally.    <br>
#
#
# </p>

# %% [markdown]
# <a id="passenger-reviews"></a>
# # <p style="padding:15px; background-color:#370B4C; font-family:fantasy; font-size:150%; color:#f2f2f0; text-align:center; border-radius: 20px 20px; font-weight:normal">3.  Passenger Reviews ⭐</p>

# %% [markdown]
# <p style="
#     font-size: 24px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #633075;
# ">
#     <b>About Section</b> 💡
# </p>
#
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#    &emsp; Here, we analyze the passenger reviews on every feature the airline offers. We try to find where there is room for improvement and we also compare the data with the overall satisfaction of the passenger in order to see the impact that every category has on the overall experience of the passenger.
# </p>

# %%
fig, ax = plt.subplots()
fig.dpi=120

sns.set_style('ticks')

ax.minorticks_on()
ax.yaxis.set_minor_locator(MultipleLocator(5000))
ax.xaxis.set_minor_locator(MultipleLocator(1))


plt.title('Satisfaction',size=20,fontweight='bold')


sns.countplot(x='Satisfaction',hue='Satisfaction',data=df,palette=['#055df5','#c23a00'])

plt.xlabel("")
plt.ylabel("Count")

plt.show()

# %%
#Making a new dataframe with only the columns that have passenger ratings and Satisfaction.
Ratings_df=df.iloc[:,8:df.shape[1]]
Ratings_df.head()
# Out:
#    Departure and Arrival Time Convenience  Ease of Online Booking  \
# 0                                       3                       3
# 1                                       2                       2
# 2                                       4                       4
# 3                                       2                       2
# 4                                       3                       3
#
#    Check-in Service  Online Boarding  Gate Location  On-board Service  \
# 0                 4                3              3                 3
# 1                 3                5              2                 5
# 2                 4                5              4                 3
# 3                 3                4              2                 5
# 4                 3                5              3                 3
#
#    Seat Comfort  Leg Room Service  Cleanliness  Food and Drink  \
# 0             5                 2            5               5
# ...

# %%
fig = plt.figure(figsize=(15,29),dpi=200)
for i,column in enumerate(Ratings_df):
    if i!=14:
        plt.subplot(8,2,i+1)
        ax=sns.countplot(x=column,hue='Satisfaction',data=Ratings_df,palette=generate_colors(2))
        ax.set_title(column,size=15)
        ax.legend(fontsize='10')
        plt.xlabel('')
        plt.ylabel('Count',size=15)
    
plt.subplots_adjust(hspace = 0.8, wspace=0.3)
fig.suptitle("Ratings Compared to Total Satisfaction",size=20,fontweight='bold',y=0.92)
plt.show()

# %% [markdown]
# <p style="
#     font-size: 30px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #370B4C;
# ">
#     <b>Analysis of the Ratings:</b> 📜
# </p>

# %% [markdown]
# <a id="departure-arrival-time-convenience"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩ Departure and Arrival Time Convenience
# </p>

# %%
values = df['Departure and Arrival Time Convenience'].value_counts(dropna=False).keys().tolist()
counts = df['Departure and Arrival Time Convenience'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 4: 31880 Passengers
# Rating 5: 27998 Passengers
# Rating 3: 22378 Passengers
# Rating 2: 21534 Passengers
# Rating 1: 19409 Passengers
# Rating 0: 6681 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
# &emsp;   Our passengers have mixed opinions about the Departure and Arrival Time Convenience. The ratings are almost evenly distributed between 1 and 5. With that in mind, the positive thing is that there are more positive or neutral ratings ( 3 through 5) than negative ones (0 through 2). From the counplot above we come to the conclusion that there is not that much correlation between total Satisfaction and Departure and Arrival Time Convenience. For instance, most people that rated the convience with 4 are also neutral or dissatisfied and the rest are close to 50-50.
# </p>

# %% [markdown]
# <a id="ease-of-online-booking"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#       color: #4A4B52;
# ">
#    ⏩ Ease of Online Booking
# </p>

# %%
values = df['Ease of Online Booking'].value_counts(dropna=False).keys().tolist()
counts = df['Ease of Online Booking'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 3: 30393 Passengers
# Rating 2: 30051 Passengers
# Rating 4: 24444 Passengers
# Rating 1: 21886 Passengers
# Rating 5: 17424 Passengers
# Rating 0: 5682 Passengers

# %% [markdown]
#  <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
#  &emsp;  First of all, the average rating seems to be neutral since most of the Passengers have rated between 2 and 4. It seems that passengers value the ease of online booking. Most passengers that have rated 1 through 3 have also been Neutral or Dissatisfied with the overall experience.Plus, most of the passengers that gave a 5 also have been satisfied with the experience which proves the point I am trying to make above.
# </p>

# %% [markdown]
# <a id="check-in-service"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩ Check-in Service
# </p>

# %%
values = df['Check-in Service'].value_counts(dropna=False).keys().tolist()
counts = df['Check-in Service'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 4: 36333 Passengers
# Rating 3: 35453 Passengers
# Rating 5: 25883 Passengers
# Rating 1: 16108 Passengers
# Rating 2: 16102 Passengers
# Rating 0: 1 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
#  &emsp;  The good news is that only one passenger has rated with 0. The overall experience with check-in seems to be pleasant (most ratings are 3-5).Furthermore, the bad experiences with check-in, which equal to bad reviews as well, seem to have a big effect on the overall experiences of the passengers (Most are Neutral or Dissatisfied).
# </p>

# %% [markdown]
# <a id="online-boarding"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩ Online Boarding
# </p>

# %%
values = df['Online Boarding'].value_counts(dropna=False).keys().tolist()
counts = df['Online Boarding'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 4: 38468 Passengers
# Rating 3: 27117 Passengers
# Rating 5: 26020 Passengers
# Rating 2: 21934 Passengers
# Rating 1: 13261 Passengers
# Rating 0: 3080 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
#   &emsp; In this rating we see a huge association between the satisfaction on Online Boarding and the overall experience of the passenger. In more detail, the people that gave a low rating on online boarding are also neutral or dissatisfied and those with a high rating are satisfied with the overall experience. Most passengers have rated between 3 and 5 which is a good sign but it seems like there is room for improvement, especially when it is a feature that passengers deem to be important.
# </p>

# %% [markdown]
# <a id="gate-location"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩ Gate Location
# </p>

# %%
values = df['Gate Location'].value_counts(dropna=False).keys().tolist()
counts = df['Gate Location'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 3: 35717 Passengers
# Rating 4: 30466 Passengers
# Rating 2: 24296 Passengers
# Rating 1: 21991 Passengers
# Rating 5: 17409 Passengers
# Rating 0: 1 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
#  &emsp;  The ratings on Gate Location are evenly spread out with most of them being positive. The Gate location doesn't have much gravity on the total satisfaction. The satisfaction is split almost 50-50 on every rating expect 3 but we can't make any assumptions from that because the rest of the ratings are almost evenly distributed, so it is probably a coincidence.
# </p>

# %% [markdown]
# <a id="on-board-service"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩ On-board Service
# </p>

# %%
values = df['On-board Service'].value_counts(dropna=False).keys().tolist()
counts = df['On-board Service'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 4: 38703 Passengers
# Rating 5: 29492 Passengers
# Rating 3: 28542 Passengers
# Rating 2: 18351 Passengers
# Rating 1: 14787 Passengers
# Rating 0: 5 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
#  &emsp;  Most reviews are from 3 to 5, which is something positive. On the other hand, the passengers that had a bad experience with the on-board service are also neutral or dissatisfied overall. This makes us come to the conclusion that a passenger's experience is hugely affect by the on-board service, which is something logical.
# </p>

# %% [markdown]
# <a id="seat-comfort"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩ Seat Comfort
# </p>

# %%
values = df['Seat Comfort'].value_counts(dropna=False).keys().tolist()
counts = df['Seat Comfort'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 4: 39756 Passengers
# Rating 5: 33158 Passengers
# Rating 3: 23328 Passengers
# Rating 2: 18529 Passengers
# Rating 1: 15108 Passengers
# Rating 0: 1 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
#  &emsp;  Again, the majority of the reviews are positive (3 to 5). On the other hand, the people that were dissatisfied by the seat comfort seem to have a bad experience overall. Most of the 1-2 ratings are neutral or dissatisfied. This shows us, that the airline should have seat comfort as a priority in order to offer the passenger a pleasant experience overall.
# </p>

# %% [markdown]
# <a id="leg-room-service"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩ Leg Room Service
# </p>

# %%
values = df['Leg Room Service'].value_counts(dropna=False).keys().tolist()
counts = df['Leg Room Service'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 4: 35886 Passengers
# Rating 5: 30905 Passengers
# Rating 3: 25056 Passengers
# Rating 2: 24540 Passengers
# Rating 1: 12895 Passengers
# Rating 0: 598 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
#  &emsp;  The leg room ratings are similar to the seat comfort ratings which is something logical. Most reviews are positive and it has a big impact on the overall experience of the passenger. At this point it is important to note that both leg room service and seat comfort are also very dependant on the class the passenger is flying on. For example, many airlines charge extra for more leg room.
# </p>

# %% [markdown]
# <a id="cleanliness"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩ Cleanliness
# </p>

# %%
values = df['Cleanliness'].value_counts(dropna=False).keys().tolist()
counts = df['Cleanliness'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 4: 33969 Passengers
# Rating 3: 30639 Passengers
# Rating 5: 28416 Passengers
# Rating 2: 20113 Passengers
# Rating 1: 16729 Passengers
# Rating 0: 14 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
#  &emsp;  Most of the ratings in this category are between 3-5 which is positive. The only correlation between the overall experience and cleanliness is at the lower ratings 1-2, where passengers are mostly neutral or dissatisfied.
# </p>

# %% [markdown]
# <a id="food-drink"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩ Food and Drink
# </p>

# %%
values = df['Food and Drink'].value_counts(dropna=False).keys().tolist()
counts = df['Food and Drink'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 4: 30563 Passengers
# Rating 5: 27957 Passengers
# Rating 3: 27794 Passengers
# Rating 2: 27383 Passengers
# Rating 1: 16051 Passengers
# Rating 0: 132 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
#  &emsp;  This category is also very dependant on the class the passenger is flying on. With that in mind, the ratings are very evenly splitted between 2-5. Again, in the negative ratings (1-2) the majority of people and neutral or dissatisfied. In the positive ratings the overall experience is almost 50-50, which means that on ratings 4-5 we can't come to any conclusions about the impact food and drink has to the overall experience of the passenger.
# </p>

# %% [markdown]
# <a id="in-flight-service"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩ In-flight Service
# </p>

# %%
values = df['In-flight Service'].value_counts(dropna=False).keys().tolist()
counts = df['In-flight Service'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 4: 47323 Passengers
# Rating 5: 34066 Passengers
# Rating 3: 25316 Passengers
# Rating 2: 14308 Passengers
# Rating 1: 8862 Passengers
# Rating 0: 5 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
#    &emsp;   The majority of the reviews are between 3-5, which is very positive. There are very few low ratings so there is not much to analyze there. The overall satisfaction is mostly neutral or dissatisfied at the low ratings but it gets better on ratings 4 and 5.
# </p>

# %% [markdown]
# <a id="in-flight-wifi-service"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩ In-flight Wifi Service
# </p>

# %%
values = df['In-flight Wifi Service'].value_counts(dropna=False).keys().tolist()
counts = df['In-flight Wifi Service'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 2: 32320 Passengers
# Rating 3: 32185 Passengers
# Rating 4: 24775 Passengers
# Rating 1: 22328 Passengers
# Rating 5: 14356 Passengers
# Rating 0: 3916 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
#  &emsp;  Most of the ratings are between 2-4 so the overall ratings is average. Looking at the data (todays society) passengers with bad wifi experience (1-3) are mostly neutral or dissatisfied, which is something that makes sense since in today's age wifi is a very important tool in our daily lives. In another note, it is important to remember that airlines charge extra for a better wifi experience and the wifi speed is also dependant on the class the passenger is flying.
# </p>

# %% [markdown]
# <a id="in-flight-entertainment"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩ In-flight Entertainment
# </p>

# %%
values = df['In-flight Entertainment'].value_counts(dropna=False).keys().tolist()
counts = df['In-flight Entertainment'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 4: 36791 Passengers
# Rating 5: 31544 Passengers
# Rating 3: 23884 Passengers
# Rating 2: 21968 Passengers
# Rating 1: 15675 Passengers
# Rating 0: 18 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
#   &emsp;The majority of the reviews are positive and most of them are between 4-5.From the plot above, we realise that In-flight entertainment has a big impact on the overall satisfaction of the passenger. In more detail, we can clearly see that people with negative or neutral experience (0-3) are mostly neutral or dissatisfied, whereas people with a positive experience are mostly overall satisfied.
# </p>

# %% [markdown]
# <a id="baggage-handling"></a>
# <p style="
#     font-size: 26px;
#     font-family: 'JetBrains Mono';
#           color: #4A4B52;
# ">
#    ⏩  Baggage Handling
# </p>

# %%
values = df['Baggage Handling'].value_counts(dropna=False).keys().tolist()
counts = df['Baggage Handling'].value_counts(dropna=False).tolist()
value_dict = dict(zip(values, counts))
for i in value_dict:
    print(f'Rating {i}: {value_dict[i]} Passengers')
# Out:
# Rating 4: 46761 Passengers
# Rating 5: 33878 Passengers
# Rating 3: 25851 Passengers
# Rating 2: 14362 Passengers
# Rating 1: 9028 Passengers

# %% [markdown]
# <p style="
#     font-size: 18px;
#     font-family: 'JetBrains Mono';
# ">
# &emsp;Another important feature is baggage handling. The majority of the reviews are positive and neutral (3-5). Pasengers with a bad experience are mostly neutral or dissatisfied, but since negative ratings are much less compared to the positive it is probably not owrth it stressing about it too much.
# </p>

# %% [markdown]
# <a id="summary"></a>
# # <p style="padding:15px; background-color:#370B4C; font-family:fantasy; font-size:150%; color:#f2f2f0; text-align:center; border-radius: 20px 20px; font-weight:normal">4.  Summary 🧐</p>

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
# ">
# &emsp;To summarise, when it comes to the overall satisfaction and experience of the passenger 60% of them are neutral or dissatisfied and 40% satisfied. There aren't any categories in which the airline has received overall negative feedback, with most of the reviews being in the range of 3 to 5. With that mind the airline should focus on improving the categories that have the biggest impact on the experience of the passenger and therefore the overall satisfaction. Some of those categories are Seat Comfort, Leg Room Service, Cleanliness, Online Boarding and Baggage Handling. That doesn't mean that there is no room for improvement in the other categories, but those mentioned above should be a priority in order to ensure an overall pleasant and happy experience.
# </p>
